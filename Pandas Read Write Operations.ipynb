# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
# dataframe is just a tabular format
draft1 = pd.read_csv('commadata.txt',sep=',') #read txt as dataframe

# %%
draft1
# Out:
#    a  b  c  d
# 0  1  2  3  4
# 1  5  6  7  8

# %%
draft1.head() #first 5 records
# Out:
#    a  b  c  d
# 0  1  2  3  4
# 1  5  6  7  8

# %%
draft1.tail() #last five records
# Out:
#    a  b  c  d
# 0  1  2  3  4
# 1  5  6  7  8

# %%
draft1.tail(1) #last one colums
# Out:
#    a  b  c  d
# 1  5  6  7  8

# %%
draft2 = pd.read_table('tabdata.tsv',sep='\t') # Read tsv into Dataframe

# %%
draft2
# Out:
#       a b c d
# 0  10 20 30 40

# %%
draft3 = pd.read_table('tabdata.tsv', header=None) # No header

# %%
draft3
# Out:
#              0
# 0     a b c d
# 1  10 20 30 40

# %%
# Giving own column name
df= pd.read_csv('commadata.txt', names=['col1','col2','col3','col4','extracol']) #pass a list of column name

# %%
df # if there is extra column the values will be NaN
# Out:
#   col1 col2 col3 col4  extracol
# 0    a    b    c    d       NaN
# 1    1    2    3    4       NaN
# 2    5    6    7    8       NaN

# %%
#multilevel indexing operation
parsed = pd.read_csv('csv_mindex.csv',index_col=['key1','key2']) #Hierarchical indexing 
parsed # we have two category repeated (one,two)
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
#Avoiding unwanted/irrelevant rows in data
pd.read_csv('ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
pd.read_csv('ex4.csv',skiprows=[0,2,3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
result= pd.read_csv('ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
#Has null values or not
pd.isnull(result) #if yes: True, else False
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
#Reading xlsx sheets
#draft4 = pd.read_excel("abcd.xlsx",sheetname='Sheet2') by default sheet1 will be read

# %%
#Read data from websites(not restricted) and has data in form of table
#where tr table tags in html
#[df1,df2,df3] multiple tables in a list will be sent(tabular data)
url = 'https://www.basketball-reference.com/leagues/NBA_2015_totals.html'
BB_data = pd.read_html(url)

# %%
BB_data[0] #first table from the list of tables(dfs)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df = BB_data[0]
df.head(10)
# Out:
#   Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0  1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1  2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2  3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3  4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4  5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# 5  5   Arron Afflalo  SG  29  DEN  53  53  1750  281  657  ...  .841   21
# 6  5   Arron Afflalo  SG  29  POR  25  19   752   94  227  ...  .851    6
# 7  6   Alexis Ajinça   C  26  NOP  68   8   957  181  329  ...  .818  104
# 8  7  Furkan Aldemir  PF  23  PHI  41   9   540   40   78  ...  .481   78
# 9  8    Cole Aldrich   C  26  NYK  61  16   976  144  301  ...  .781  101
#
#    DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  222  301   68  27  22   60  147   398
# 1   19   28   16  16   7   14   24    94
# ...

# %%
df.tail(10)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 665  485  Brandan Wright  PF  27  PHO  40   7   858  120  207  ...  .667   70
# 666  486   Dorell Wright  SF  29  POR  48   2   592   72  190  ...  .810   14
# 667  487     Tony Wroten  PG  21  PHI  30  15   895  175  434  ...  .667   22
# 668  488     James Young  SG  19  BOS  31   0   332   36  102  ...  .552    9
# 669  489      Nick Young  SG  29  LAL  42   0  1000  174  476  ...  .892   17
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 665  124  194   23   32  47   16   54   280
# ...

# %%
df['Player']
# Out:
# 0          Quincy Acy
# 1        Jordan Adams
# 2        Steven Adams
# 3         Jeff Adrien
# 4       Arron Afflalo
#             ...
# 670    Thaddeus Young
# 671    Thaddeus Young
# 672    Thaddeus Young
# 673       Cody Zeller
# 674      Tyler Zeller
# Name: Player, Length: 675, dtype: object

# %%
#Read Multiple Column
df[['Player','Tm']] #for multiple columns use list([])
# Out:
#              Player   Tm
# 0        Quincy Acy  NYK
# 1      Jordan Adams  MEM
# 2      Steven Adams  OKC
# 3       Jeff Adrien  MIN
# 4     Arron Afflalo  TOT
# ..              ...  ...
# 670  Thaddeus Young  TOT
# 671  Thaddeus Young  MIN
# 672  Thaddeus Young  BRK
# 673     Cody Zeller  CHO
# 674    Tyler Zeller  BOS
#
# [675 rows x 2 columns]

# %%
type(df['MP'])
# Out:
# pandas.core.series.Series

# %%
#series - one row or one column - partially correct
#dataframe- collection of series - we can say!

# %%
type(df[['MP']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
#Read data from github 
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic[['Name','PassengerId']].head(10)
# Out:
#                                                 Name  PassengerId
# 0                            Braund, Mr. Owen Harris            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2                             Heikkinen, Miss. Laina            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 4                           Allen, Mr. William Henry            5
# 5                                   Moran, Mr. James            6
# 6                            McCarthy, Mr. Timothy J            7
# 7                     Palsson, Master. Gosta Leonard            8
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9
# 9                Nasser, Mrs. Nicholas (Adele Achem)           10

# %%
type(titanic['PassengerId'])
# Out:
# pandas.core.series.Series

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic['Name'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# # Small Task

# %%
#Read this data in df
#Print first five data
#print last two data
#give your own column name
#Select one column and print data type
#check data into anydata is null
#skip random rows

# %%
gitdata = pd.read_csv('https://gist.githubusercontent.com/rnirmal/e01acfdaf54a6f9b24e91ba4cae63518/raw/6b589a5c5a851711e20c5eb28f9d54742d1fe2dc/datasets.csv')

# %%
gitdata.head(10)
# Out:
#             datasetName                                            about  \
# 0    Microbiome Project                American Gut (Microbiome Project)
# 1                 GloBI               Global Biotic Interactions (GloBI)
# 2        Global Climate                   Global Climate Data Since 1929
# 3       CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4     Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# 5  Criteo click-through                        Criteo click-through data
# 6            ICWSM 2009                ICWSM Data Challenge (since 2009)
# 7               KDD Cup                          KDD Cup by Tencent 2012
# 8       Localytics Data          Localytics Data Visualization Challenge
# 9          Yelp Dataset                           Yelp Dataset Challenge
#
#                                                 link       categoryName  \
# 0            https://github.com/biocore/American-Gut            Biology
# ...

# %%
gitdata.tail(10)
# Out:
#         datasetName                                              about  \
# 51          UK-DALE  UK Domestic Appliance-Level Electricity (UK-DA...
# 52        Landsat 8                                   Landsat 8 on AWS
# 53  Reverse Geocode  Simple but fast reverse geocoding up to city g...
# 54   Faces Database                        10k US Adult Faces Database
# 55   ClueWeb09 FACC                                     ClueWeb09 FACC
# 56   ClueWeb12 FACC                                     ClueWeb12 FACC
# 57    Google Ngrams                        Google Books Ngrams (2.2TB)
# 58       EDRM Enron        EDRM Enron EMail of 151 users, hosted on S3
# 59          GetGlue                    GetGlue - users rating TV shows
# 60   Twitter RepLab      Twitter Data for Online Reputation Management
#
#                                                  link      categoryName  \
# 51              http://www.doc.ic.ac.uk/~dk3810/data/            Energy
# ...

# %%
gitdata.rename(columns={'datasetName':'Company'},inplace =True)

# %%
gitdata.head()
# Out:
#               Company                                            about  \
# 0  Microbiome Project                American Gut (Microbiome Project)
# 1               GloBI               Global Biotic Interactions (GloBI)
# 2      Global Climate                   Global Climate Data Since 1929
# 3     CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4   Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
#
#                                                 link       categoryName  \
# 0            https://github.com/biocore/American-Gut            Biology
# 1  https://github.com/jhpoelen/eol-globi-data/wik...            Biology
# 2                     http://en.tutiempo.net/climate    Climate/Weather
# 3  http://www.bigdatanews.com/profiles/blogs/big-...  Computer Networks
# 4  http://cnets.indiana.edu/groups/nan/webtraffic...  Computer Networks
#
#     cloud  vintage
# 0  GitHub      NaN
# 1  GitHub      NaN
# 2     NaN   1929.0
# 3     NaN   2012.0
# ...

# %%
gitdata['Company'].dtypes
# Out:
# dtype('O')

# %%
gitdata.isnull()
# Out:
#     Company  about   link  categoryName  cloud  vintage
# 0     False  False  False         False  False     True
# 1     False  False  False         False  False     True
# 2     False  False  False         False   True    False
# 3     False  False  False         False   True    False
# 4     False  False  False         False   True     True
# ..      ...    ...    ...           ...    ...      ...
# 56    False  False  False         False   True    False
# 57    False  False  False         False  False     True
# 58    False  False  False         False  False     True
# 59    False  False  False         False   True     True
# 60    False  False  False         False   True    False
#
# [61 rows x 6 columns]

# %%
data1 = pd.read_csv('https://gist.githubusercontent.com/rnirmal/e01acfdaf54a6f9b24e91ba4cae63518/raw/6b589a5c5a851711e20c5eb28f9d54742d1fe2dc/datasets.csv',skiprows=[1,2,3])

# %%
data1.head()
# Out:
#             datasetName                                            about  \
# 0       CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 1     Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# 2  Criteo click-through                        Criteo click-through data
# 3            ICWSM 2009                ICWSM Data Challenge (since 2009)
# 4               KDD Cup                          KDD Cup by Tencent 2012
#
#                                                 link       categoryName cloud  \
# 0  http://www.bigdatanews.com/profiles/blogs/big-...  Computer Networks   NaN
# 1  http://cnets.indiana.edu/groups/nan/webtraffic...  Computer Networks   NaN
# 2  http://labs.criteo.com/2015/03/criteo-releases...  Computer Networks   NaN
# 3                          http://icwsm.cs.umbc.edu/    Data Challenges   NaN
# 4                         http://www.kddcup2012.org/    Data Challenges   NaN
#
#    vintage
# 0   2012.0
# 1      NaN
# 2      NaN
# ...

# %%
data1['about'].dtype
# Out:
# dtype('O')

# %%
#remove index
data2 = data1.to_csv('saved.csv',index=False,header=False)

# %%
dummy = pd.read_csv('ex4.csv',nrows=3)

# %%
dummy
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN

# %%
#chunksize - data read opearation - only with the given size(byte)
# if 1 row size = 30 byte size, chunk size = 100, we can get 3 rows = 90 < 100.
dummy1 = pd.read_csv('ex4.csv',chunksize=1000) # not used

# %%
dummy1 # we have to iterate

# %%
for i in dummy1:
    print(i)
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
data5 = pd.read_csv('ex5.csv')

# %%
data5
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# # Write data

# %%
data5.to_csv('newnamedata5.csv')

# %%
#but i dont want index and header
data5.to_csv('newnamedata5.csv',index=False,header=False)

# %%
 #new seperator or change seperator
data5.to_csv('newnamedata6.csv',sep='@',index=False,header=False)

# %%
#If i dont want to save the file, but keep in a clipboard using sys.stdout
import sys
data5.to_csv('out1.csv',na_rep='Missing') # na_rep = missing data replacement

# %%
pd.read_csv('out1.csv')
# Out:
#    Unnamed: 0 something  a   b        c   d  message
# 0           0       one  1   2      3.0   4  Missing
# 1           1       two  5   6  Missing   8    world
# 2           2     three  9  10     11.0  12      foo

# %%
data5.to_csv('out1.csv',columns=['a','b','c'])

# %%
pd.read_csv('out1.csv')
# Out:
#    Unnamed: 0  a   b     c
# 0           0  1   2   3.0
# 1           1  5   6   NaN
# 2           2  9  10  11.0

# %% [markdown]
# # DateRange

# %%
dates = pd.date_range('1/1/2000',periods=7)  #startdate, end date, period(days)

# %%
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
ts = pd.Series(np.arange(7),index=dates)

# %%
ts
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-03    2
# 2000-01-04    3
# 2000-01-05    4
# 2000-01-06    5
# 2000-01-07    6
# Freq: D, dtype: int32

# %%
ts.to_csv('tseries.csv')

# %%
values =[1,2,3]
zip(values)

# %% [markdown]
# # JSON

# %%
obj = {
	"id": "0001",
	"type": "donut",
	"name": "Cake",
	"ppu": 0.55,
	"batters":
		{
			"batter":
				[
					{ "id": "1001", "type": "Regular" },
					{ "id": "1002", "type": "Chocolate" },
					{ "id": "1003", "type": "Blueberry" },
					{ "id": "1004", "type": "Devil's Food" }
				]
		},
	"topping":
		[
			{ "id": "5001", "type": "None" },
			{ "id": "5002", "type": "Glazed" },
			{ "id": "5005", "type": "Sugar" },
			{ "id": "5007", "type": "Powdered Sugar" },
			{ "id": "5006", "type": "Chocolate with Sprinkles" },
			{ "id": "5003", "type": "Chocolate" },
			{ "id": "5004", "type": "Maple" }
		]
}

# %%
obj
# Out:
# {'id': '0001',
#  'type': 'donut',
#  'name': 'Cake',
#  'ppu': 0.55,
#  'batters': {'batter': [{'id': '1001', 'type': 'Regular'},
#    {'id': '1002', 'type': 'Chocolate'},
#    {'id': '1003', 'type': 'Blueberry'},
#    {'id': '1004', 'type': "Devil's Food"}]},
#  'topping': [{'id': '5001', 'type': 'None'},
#   {'id': '5002', 'type': 'Glazed'},
#   {'id': '5005', 'type': 'Sugar'},
#   {'id': '5007', 'type': 'Powdered Sugar'},
#   {'id': '5006', 'type': 'Chocolate with Sprinkles'},
#   {'id': '5003', 'type': 'Chocolate'},
#   {'id': '5004', 'type': 'Maple'}]}

# %%
import json
result = json.dumps(obj) #json must be string
type(result)
# Out:
# str

# %%
result[0:10]
# Out:
# '{"id": "00'

# %%
[{"a":1,"b":2},
 {"a":3,"b":4},
 {"a":5,"b":6}
]
# Out:
# [{'a': 1, 'b': 2}, {'a': 3, 'b': 4}, {'a': 5, 'b': 6}]

# %%
print(obj.to_json())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-15c1532c29e7> in <module>
# ----> 1 print(obj.to_json())
#
# AttributeError: 'dict' object has no attribute 'to_json'

# %% [markdown]
# # HTML XML

# %%
tables = pd.read_html('table.html')
tables[0]
tables.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-3baa747a5561> in <module>
# ----> 1 tables = pd.read_html('table.html')
#       2 tables[0]
#       3 tables.head()
#
# F:\Anacondareinstall\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# F:\Anacondareinstall\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
#    1112         keep_default_na=keep_default_na,
# -> 1113         displayed_only=displayed_only,
#    1114     )
#
# ...

# %% [markdown]
# # Binary data Format

# %%
frame = pd.read_csv('ex5.csv')

# %%
#serde operation #Serialization
frame.to_pickle('frame_pickle') #obj to binary code

# %%
pd.read_pickle('frame_pickle') #deserialiazation
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# # HDF5 Format

# %%
frame1 = pd.DataFrame({'a':np.random.randn(100)})
store = pd.HDFStore('mydata.hS')
store['obj1'] = frame
store['obj1_col']=frame['a']
store
# Out:
# F:\Anacondareinstall\lib\site-packages\IPython\core\interactiveshell.py:3331: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['something', 'message'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.hS

# %%
frame1 = pd.DataFrame({'a':np.random.randn(100)})
frame1
# Out:
#            a
# 0   0.646950
# 1  -1.001417
# 2  -0.076479
# 3  -0.610786
# 4  -1.446169
# ..       ...
# 95 -0.877070
# 96  0.842590
# 97  0.344468
# 98 -1.457516
# 99  0.187796
#
# [100 rows x 1 columns]

# %%
store['obj1_col']
# Out:
# 0    1
# 1    5
# 2    9
# Name: a, dtype: int64

# %% [markdown]
# # Web API

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43862',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43862/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43862/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43862/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43862',
#   'id': 1014430557,
#   'node_id': 'PR_kwDOAA0YD84smtJQ',
#   'number': 43862,
#   'title': 'PERF: get_loc',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
# ...

# %%
data[0]['user']
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
# ...

# %%
data[0]['user']['id']
# Out:
# 8078968

# %%
l=[]
for i in range(len(data)):
    l.append(data[i]['user']['id'])

# %%
l
# Out:
# [8078968,
#  46123408,
#  40593450,
#  39504233,
#  31819322,
#  8078968,
#  6618166,
#  6618166,
#  8078968,
#  375307,
#  8078968,
#  160132,
#  31899203,
#  39696536,
#  39696536,
#  54274219,
#  31857876,
#  8078968,
#  6618166,
#  37011898,
#  89147478,
#  45828280,
#  38472982,
#  24256554,
#  6618166,
#  16756448,
#  14806954,
#  38472982,
#  38295417,
#  6618166]

# %%
issues = pd.DataFrame(data,columns=['labels','title'])

# %%
issues
# Out:
#                                                labels  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 4   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 5                                                  []
# 6   [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...
# 7   [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...
# 8   [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2OD...
# 9   [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...
# 10  [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2OD...
# 11  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...
# 12  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...
# 13  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...
# 14  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...
# 15  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...
# ...
